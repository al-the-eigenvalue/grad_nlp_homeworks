# %% [markdown]
# # Домашнее задание № 4. Языковые модели

# %%
# %%capture
# !pip install razdel

# %%
import nltk
import numpy as np
import re

from collections import Counter
from nltk.tokenize import sent_tokenize
from scipy.sparse import lil_matrix, csc_matrix
from sklearn.model_selection import train_test_split
from string import punctuation
from razdel import tokenize as razdel_tokenize

# %%
nltk.download("punkt_tab")
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %% [markdown]
# ## Задание 1 (8 баллов).

# %% [markdown]
# В семинаре для генерации мы использовали предположение маркова и считали, что слово зависит только от 1 предыдущего слова. Но ничто нам не мешает попробовать увеличить размер окна и учитывать два или даже три прошлых слова. Для них мы еще сможем собрать достаточно статистик и, логично предположить, что качество сгенерированного текста должно вырасти.

# %% [markdown]
# Попробуйте сделать языковую модель, которая будет учитывать два предыдущих слова при генерации текста.
# Сгенерируйте несколько текстов (3-5) и расчитайте перплексию получившейся модели.
# Можно использовать данные из семинара или любые другие (можно брать только часть текста, если считается слишком долго). Перплексию рассчитывайте на 10-50 отложенных предложениях (они не должны использоваться при сборе статистик).
#
#
# Подсказки:
#     - нужно будет добавить еще один тэг \<start>
#     - можете использовать тот же подход с матрицей вероятностей, но по строкам хронить биграмы, а по колонкам униграммы
#     - тексты должны быть очень похожи на нормальные (если у вас получается рандомная каша, вы что-то делаете не так)
#     - у вас будут словари с индексами биграммов и униграммов, не перепутайте их при переводе индекса в слово - словарь биграммов будет больше словаря униграммов и все индексы из униграммного словаря будут формально подходить для словаря биграммов (не будет ошибки при id2bigram[unigram_id]), но маппинг при этом будет совершенно неправильным

# %% [markdown]
# Создадим корпус, токенизируем, поделим на train (для сбора статистик для марковской модели) и val (для подсчета переплексии).

# %%
news = open("lenta.txt").read()

# %%
def normalize(text):
    normalized_text = [
        word.text.strip(punctuation)
        for word in razdel_tokenize(text)
    ]
    normalized_text = [
        word.lower() for word in normalized_text
        if word and len(word) < 20
    ]
    return normalized_text

# %%
sents_news = [
    ["<start>"] * 2 + normalize(text) + ["<end>"]
    for text in sent_tokenize(news[:5000000])
]
sents_news_train, sents_news_val = train_test_split(
    sents_news, test_size=50, random_state=42
)

# %% [markdown]
# Создадим Counters для униграмм, биграмм и триграмм.

# %%
def ngrammer(tokens, n=2):
    ngrams = []
    for i in range(0, len(tokens)-n+1):
        ngrams.append(" ".join(tokens[i:i+n]))
    return ngrams

# %%
unigrams_news = Counter()
bigrams_news = Counter()
trigrams_news = Counter()

for sentence in sents_news_train:
    unigrams_news.update(sentence)
    bigrams_news.update(ngrammer(sentence))
    trigrams_news.update(ngrammer(sentence, n=3))

# %% [markdown]
# Создадим матрицу вероятностей, в которой по строкам хранятся биграммы, а по колонкам униграммы.

# %%
matrix_news = lil_matrix(
    (len(bigrams_news), len(unigrams_news))
)

id2word_news = list(unigrams_news)
word2id_news = {word:i for i, word in enumerate(id2word_news)}

id2bigram_news = list(bigrams_news)
bigram2id_news = {bigram:i for i, bigram in enumerate(id2bigram_news)}

for trigram in trigrams_news:
    bigram, word = trigram.rsplit(" ", 1)
    matrix_news[
        bigram2id_news[bigram],
        word2id_news[word]
    ] = (trigrams_news[trigram] / bigrams_news[bigram])

matrix_news = csc_matrix(matrix_news)

# %% [markdown]
# Перепишем функцию generate так, чтобы она генерировала следующее слово на основе любых n-грамм:

# %%
def generate(
    matrix, id2word, ngram2id, total_tokens=100, n=1
):
    start = " ".join(["<start>"] * n)
    text = []
    current_idx = ngram2id[start]
    prev_words = ["<start>"] * (n - 1)

    for i in range(total_tokens):
        chosen_idx = np.random.choice(
            matrix.shape[1],
            p=matrix[current_idx].toarray()[0]
        )
        chosen_word = id2word[chosen_idx]
        text.append(chosen_word)

        if chosen_word == "<end>":
            prev_words = ["<start>"] * (n - 1)
            chosen_word = "<start>"

        prev_words.append(chosen_word)
        current_idx = ngram2id[" ".join(prev_words)]
        prev_words = prev_words[1:]

    generation = re.sub(r"<end> ?", "\n", " ".join(text))
    return generation

# %% [markdown]
# ### Генерации

# %%
for i in range(1, 6):
    print(f"Генерация {i}:")
    print(generate(matrix_news, id2word_news, bigram2id_news, n=2))
    print()
# Out:
# Генерация 1:
# на их территорию в радиусе одного километра от места крушения
# поскольку данные материалы до настоящего момента он работал директором департамента информации и о причинах катастрофы нет обломки протона упали в первые минуты после заявления своей цены и призвал всех иностранцев спокойно работать
# любой получатель спирта в столице около 30 тысяч дел заведенных на граждан страны на следующей неделе группа британских масонов из йоркшира задавшись целью приподнять завесу таинственности окутывающую деятельность масонов и стать более совершенным человеком
# два взрыва между собой оба теракта
# позднее они отказались сообщить подробности
# по словам заместителя генерального прокурора александр розанов заменил
#
# Генерация 2:
# управделами президента павлом бородиным именно он может произойти землетрясение силой почти 8 баллов принес обширные наводнения и оползни
# на принятие адекватных мер по предотвращению территористических акций
# вместе с тем что голосование нельзя признать состоявшимся поскольку у американских правоохранительных органов 19-летний пострадавший находится сейчас в кабинете президента а не с фискальной а с объемной долей спирта свыше 25 за исключением дежурных
# в настоящее время эта сеть должна использоваться в генетическом моделировании
# к месту катастрофы эрики вышли два морских буксира
# как передает риа новости сообщил начальник отдела управления федеральных таможенных доходов российского бюджета перетекали в mabetex
#
#
# Генерация 3:
# он считает что российское оружие покидает территорию республики сообщает интерфакс
# канцелярия премьер-министра заявила о необходимости пресекать факты когда арендные ставки на распространение программы в рамках окончательного урегулирования ближневосточного конфликта
# в свою очередь будет пересылать их профессору уорвик задается вопросом будут ли истцы требовать выделения деятельности microsoft в ходе освобождения урус-мартана
# однако власти города надеются что им получены вызывающие беспокойство сообщения о ранении или ухудшении своего здоровья
# документы подготовлены комиссией госдумы по восьми одномандатным округам 141 кандидат
# он процитировал политический раздел нового документа в четвертом чтении проекта бюджета-2000 госдума в свою очередь доренко также обратился к
#
# Генерация 4:
# любой желающий может отправиться к примеру в великобритании лейбористской партии на всеобщих выборах робертсон стал министром обороны чечни магомедом ямбиевым
# с точки зрения влияния на ход торгов продолжает оказывать информация о возможных последствиях доступа к богатейшему литературному собранию
# в соответствии с законодательством принять какие-то последующие действия в интернете открылся персональный сайт экс-премьера рф сергея степашина бандитский произвол стал в черном ящике еще не получено но представители concert ожидают его в суде
# исследование показало что системы защиты dvd от незаконного копирования произошел в минувший вторник в москве это соотношение составляет около 1,7 миллиарда рублей
# как сказал он
#
# Генерация 5:
# их будет не выше чем минимальный уровень пенсий абсолютно недопустимо
# мы готовы к наступлению 2000 года
# путин также отметил что компания не участвовала
# все имущество собора застраховано но оформлено как единое целое
# офицер балтийского флота признал виновным в попытке нанесения телесных повреждений на линиях электропередачи оказались временно лишенными электроэнергии 848000 семей
# состав который отправится в ингушетию где намерена на месте получили правдивую информацию о том что сейчас проводятся испытания в таиланде отныне эти провайдеры будут свободный доступ правительство россии обязывается до 1 миллиарда операций с картами europay
# однако в районе аэропорта южно-сахалинск
# компьютер

# %% [markdown]
# ### Перплексия

# %%
def compute_join_proba_markov_assumption(
    text, smaller_ngram_counts, ngram_counts,
    n=1, tokenized=True
):
    prob = 0
    if tokenized:
        tokenized_text = text
    else:
        tokenized_text = ["<start>"] * n + normalize(text) + ["<end>"]

    for ngram in ngrammer(tokenized_text, n=n+1):
        left_ngram, word = ngram.rsplit(" ", 1)
        if left_ngram in smaller_ngram_counts and ngram in ngram_counts:
            prob += np.log(
                ngram_counts[ngram] / smaller_ngram_counts[left_ngram]
            )
        else:
            prob += np.log(2e-5)
    return prob, len(tokenized_text) - n - 1

# %%
def perplexity(logp, N):
    return np.exp((-1/N) * logp)

# %%
def mean_perplexity(
    data_list, smaller_ngram_counts,
    ngram_counts, n=1, tokenized=True,
    print_logs=True
):
    ppl_sum = 0
    for sent in data_list:
        if print_logs:
            if tokenized:
                print(" ".join(sent[n:-1]))
            else:
                print(sent)

        current_ppl = perplexity(
            *compute_join_proba_markov_assumption(
                sent, smaller_ngram_counts, ngram_counts,
                n=n, tokenized=tokenized
            )
        )
        ppl_sum += current_ppl
        if print_logs:
            print("Перплексия:", current_ppl, "\n")
    return ppl_sum / len(data_list)

# %%
perplexity_val = mean_perplexity(
    sents_news_val, bigrams_news, trigrams_news, n=2
)
# Out:
# центральная избирательная комиссия утвердила перечень подлежащих опубликованию сведений о доходах и имуществе зарегистрированного кандидата на должность президента россии а также его супруги или супруга и детей
# Перплексия: 804.866412443738
#
# е e причиной стала ошибка рабочих заливших в систему слишком много урановой смеси что привело к взрыву
# Перплексия: 30058.841783487525
#
# идея построить мост через керченский пролив впервые пришла в голову немецкому министру вооружений альберту шпееру весной 1943 года
# Перплексия: 24214.08364882088
#
# по словам представителей сирии переговоры действительно были отложены и стороны договариваются о новой дате очередного этапа переговорного процесса
# Перплексия: 22558.37948352929
#
# тем не менее он не считает что это окончательная победа здравого смысла и справедливости в 2000 году во всех московских домах появятся консьержи и все подъезды будут оборудованы кнопкой тревожной сигнализации
# Перплексия: 8681.802224985502
#
# стоимость перерегистрации домена также составит 36 долларов
# Перплексия: 141636.35636728094
#
# как сообщает риа новости затронув вопрос о скандальных обвинениях в адрес россии в связи с международными финансовыми операциями госсекретарь сообщила что в настоящее время по этом вопросу в сша проводится тщательное расследование
# Перплексия: 1766.8731701432516
#
# данные протокола об итогах голосования могут передаваться в электронном виде по каналам государственной автоматизированной системы выборы в вышестоящую избирательную комиссию более 650 человек погибли в результате выхода рек из берегов и многочисленных оползней заявил в воскресенье журналистам reuters президент венесуэлы уго чавес
# Перплексия: 5872.6567952539335
#
# по словам скуратова в беседе с представителями генпрокуратуры он подтвердил что у него есть достаточные основания утверждать что окружение президента было заинтересовано в его отставке
# Перплексия: 4509.526787813553
#
# мвд находятся рядом
# Перплексия: 1102930.6607566762
#
# бандиты проходили обучение в диверсионном лагере в чечне
# Перплексия: 45972.94566402609
#
# тем не менее польскаясистема здравоохранения хорошоподготовлена к вирусной экспансии полторамиллиона граждан каждый 25-й поляк прошликурс противогриппозной вакцинации
# Перплексия: 19629.796918144824
#
# так в предисловии он объясняет что этот сайт только для взрослых в том смысле что я хотел бы найти собеседника способного думать и делать свой собственный выбор
# Перплексия: 29545.716924217388
#
# по мнению правительства сша те институты которые не хотят ставить заслоны на пути грязных денег должны сами за это платить
# Перплексия: 29058.310524746023
#
# мой сайт в настоящее время находится в стадии создания
# Перплексия: 8554.46902861184
#
# адвокаты страховых компаний поясняют что истцы основываются на хлипком аргументе корнями уходящем в морское законодательство xix столетия
# Перплексия: 78218.12652923234
#
# 14 тысяч 890 из них содержали закрытую информацию которую рассекречивать по прошествии 25 лет как поступают обычно с документами с грифом секретно вовсе не следовало
# Перплексия: 70494.97959896167
#
# 96 крупнейших американских корпораций могут быть не готовы к смене года с 1999 на 2000 выяснила исследовательская компания weiss ratings анализируя опубликованные этими корпорациями балансы и бюджеты
# Перплексия: 24135.21698153078
#
# для изучения этого опасного явления фбр осуществляет специальный проект под кодовым названием project megiddo
# Перплексия: 34679.62884973787
#
# это 89 зарубежная поездка иоанна павла ii
# Перплексия: 19971.569625051863
#
# всего у председателягосдумы будет шесть заместителей от каждой фракции по одному
# Перплексия: 16324.397293673544
#
# правительство сша по мнению этих респондентов должно разработать систему классификации информации в сети
# Перплексия: 11762.895746067295
#
# госдепартамент издал предписание для граждан находящихся за пределами сша
# Перплексия: 1896.2287038522095
#
# другое дело как возникло это сочинение в том числе в телевизионном изображении
# Перплексия: 9862.742759280556
#
# для этого оно просит выделить в текущем году 75 миллионов долларов и еще 140 миллионов долларов на следующие два года
# Перплексия: 1774.6292161820138
#
# ожидается что по итогам поездки министр даст пресс-конференцию в моздоке у бориса березовского нет ни одной акции аэрофлота
# Перплексия: 6236.654963608623
#
# кроме того выпустив на вполнезаконных основаниях альбом григория гладкова дурак зеко неуказала на обложке альбома автора песни девушка с отбойныммолотком владимира москвина нарушив таким образом его право на имя корпорация taxware international предложила проект решения проблемы налогообложения электронных продаж сообщает pc week
# Перплексия: 42764.98556257414
#
# на протяжении почти 40 лет стабильным поставщиком вооружений для армии и флота пакистана остается кнр
# Перплексия: 14002.08712564589
#
# в короткое время он сделался настолько известен что в сети появился его двойник антилужковской направленности военная прокуратура северного флота установила что условия хранения боеприпасов и взрывчатых веществ на базах и складах флота не соответствуют положениям закона рф об оружии
# Перплексия: 19211.98607254218
#
# об этом итар-тасс сообщили источники в правоохранительных органах грузии
# Перплексия: 16.683576488841073
#
# вечером по традиции же в киноконцертном зале россия состоится праздничный концерт посвященный дню милиции в котором примут участие известныеэстрадные исполнители
# Перплексия: 32567.34602893178
#
# как сообщает агентство риа новости поводом к рассмотрению явилась жалоба петербургского энергомашбанка
# Перплексия: 1020.865843159246
#
# условия соглашения оглашены не были
# Перплексия: 63995.12967058698
#
# как сообщила радиостанция эхо москвы в результате взрыва пострадали два человека потерпев поражение в дагестане шамиль басаев объявил о намерении создать специальное подразделение исламских камикадзе
# Перплексия: 2689.5323722850944
#
# как отмечается в заявлении министерства в последние дни эмоциональное напряжение существующее в обществе стало выплескиваться в ряде сми в совершенно недопустимых формах
# Перплексия: 5990.360879817246
#
# представители лукойла на собрании отсутствовали
# Перплексия: 158371.4539799098
#
# как сообщает риа новости приморские метеорологи еще три дня назад предупредили жителей о приближении очередного циклона
# Перплексия: 5248.579409161572
#
# возможно я вернусь во францию против мужа беназир бхутто пакистанавыдвинуто еще одно обвинение в покровительстве группе дельцов организовавших масштабное производство и нелегальную средств за рубеж
# Перплексия: 30741.795877982146
#
# по данным авн за два дня до преступления алексеенко высказывал мысли о захвате оружия автомобиля и побеге в тайгу
# Перплексия: 11359.167051880802
#
# как сообщает интерфакс со ссылкой на источники в московской мэрии в иске лужков ссылается на конституцию рф которая относит кадровые вопросы в регионах к совместному ведению органов федеральной и местной власти
# Перплексия: 4309.879587760826
#
# таким образом можно считать что купюра реально превратилась в сторублевую
# Перплексия: 2526.002711539694
#
# разрабатывается версия заказного убийства всего несколько месяцев назад в кабинет шумляева соратника тулеева и активного политического деятеля региона была брошена граната правительство россии повысило в 1,5 раза должностные оклады работников занимающих должности не отнесенные к государственным должностям и осуществляющих техническое обеспечение деятельности федеральных государственных органов включая территориальные органы федеральных органов исполнительной власти аппаратов федеральных судов и органов прокуратуры
# Перплексия: 18271.267658658955
#
# по данным пресс-центра на направлении артиллерия нанесла удары по разведгруппе боевиков проводившей разведку подступов и района обороны федеральных сил
# Перплексия: 16257.833103456005
#
# клонирование предполагается провести по схеме послужившей два года назад для создания в шотландии овцы долли
# Перплексия: 56834.517593457174
#
# по имеющейся оперативной информации инициатором и вдохновителем этой акции является террорист бин ладен 9 сентября около трех часов ночи практически одновременно прогремели взрывы во дворах домов директора пушного хозяйства владимира титоренко доверенного лица генерала семенова на процессах в верховном суде карачаево-черкесии георгия токарева и атамана баталпашинского отдела кубанского казачьего войска николая первакова
# Перплексия: 32130.125694070997
#
# эти теракты он расценивает как попытку запугать народ и парализовать политическое руководство страны
# Перплексия: 48335.80069737056
#
# теперь кубинцы требуют немедленно возвратить элиана родному отцу
# Перплексия: 102654.25767609241
#
# в то же время яблоко по-прежнему отказывается от поста заместителя председателя госдумы
# Перплексия: 1076.2591856428053
#
# никто из сотрудников генерального консульства рф в салониках и членов их семей не пострадал
# Перплексия: 2324.1295402688465
#
# во вторник около часа ночи в петербурге на улице есенина взорвался бензовоз
# Перплексия: 4155.176946536082

# %% [markdown]
# Средняя перплексия модели на валидационном датасете:

# %%
perplexity_val
# Out:
# 48560.1516120636

# %% [markdown]
# Средняя перплексия модели на фрагменте трейна (ожидаемо меньше):

# %%
mean_perplexity(
    sents_news_train[:1000], bigrams_news, trigrams_news, n=2,
    print_logs=False
)
# Out:
# 37.09537163547413

# %% [markdown]
# ## Задание № 2* (2 балла).

# %% [markdown]
# Измените функцию generate_with_beam_search так, чтобы она работала с моделью, которая учитывает два предыдущих слова.
# Сравните получаемый результат с первым заданием.
# Также попробуйте начинать генерацию не с нуля (подавая \<start> \<start>), а с какого-то промпта. Но помните, что учитываться будут только два последних слова, так что не делайте длинные промпты.

# %%
class Beam:
    def __init__(self, sequence: list, score: float):
        self.sequence: list = sequence
        self.score: float = score

# %%
def generate_with_beam_search(
    matrix, id2word, ngram2id,
    total_tokens=100, max_beams=5,
    n=1, prompt=""
):
    # изначально у нас один луч с заданным началом (start по дефолту)
    initial_node = Beam(
        sequence=["<start>"] * n + normalize(prompt),
        score=np.log1p(0)
    )
    beams = [initial_node]

    for i in range(total_tokens):
        # делаем total_tokens шагов генерации
        new_beams = []
        # на каждом шаге продолжаем каждый из имеющихся лучей
        for beam in beams:
            # лучи которые уже закончены не продолжаем (но и не удаляем)
            if beam.sequence[-1] == "<end>":
                new_beams.append(beam)
                continue

            # наша языковая модель предсказывает на основе предыдущей n-граммы
            # достанем его из beam.sequence
            last_id = ngram2id[" ".join(beam.sequence[-n:])]

            # посмотрим вероятности продолжений для предыдущей n-граммы
            probas = matrix[last_id].toarray()[0]

            # возьмем топ самых вероятных продолжений
            top_idxs = probas.argsort()[:-(max_beams+1):-1]
            for top_id in top_idxs:
                # иногда вероятности будут нулевые, такое не добавляем
                if not probas[top_id]:
                    break

                # создадим новый луч на основе текущего и варианта продолжения
                new_sequence = beam.sequence + [id2word[top_id]]
                # скор каждого луча это произведение вероятностей (или сумма логарифмов)
                new_score = (beam.score + np.log1p(probas[top_id])) / len(new_sequence)
                new_beam = Beam(sequence=new_sequence, score=new_score)
                new_beams.append(new_beam)
        # отсортируем лучи по скору и возьмем только топ max_beams
        beams = sorted(new_beams, key=lambda x: x.score, reverse=True)[:max_beams]

    sorted_sequences = sorted(beams, key=lambda x: x.score, reverse=True)
    sorted_sequences = [" ".join(beam.sequence[n:-1]) for beam in sorted_sequences]
    return sorted_sequences

# %% [markdown]
# Генерация с нуля:

# %%
generate_with_beam_search(
    matrix_news, id2word_news,
    bigram2id_news, max_beams=10, n=2,
)
# Out:
# ['как сообщили риа новости',
#  'как сообщает риа новости',
#  'об этом риа новости',
#  'об этом сообщает риа новости',
#  'об этом сообщает агентство риа новости',
#  'об этом сообщает риа новости со ссылкой на пресс-центр мвд участники совещания заслушали руководителей подразделений на приоритетных направлениях работы защите экономики от криминального влияния ”',
#  'об этом сообщает риа новости со ссылкой на пресс-центр объединенной группировки войск на северном кавказе',
#  'об этом сообщает риа новости со ссылкой на пресс-центр мвд участники совещания заслушали руководителей подразделений на территории чечни',
#  'об этом сообщает риа новости со ссылкой на пресс-центр объединенной группировки федеральных войск на северном кавказе',
#  'об этом сообщает риа новости со ссылкой на пресс-центр мвд участники совещания заслушали руководителей подразделений на приоритетных направлениях работы защите экономики от криминального влияния противодействии наркомании и борьбе с терроризмом']

# %% [markdown]
# Генерации с промптами:

# %%
generate_with_beam_search(
    matrix_news, id2word_news,
    bigram2id_news, max_beams=10, n=2,
    prompt="в санкт-петербурге"
)
# Out:
# ['в санкт-петербурге а вернее в петербургском интернете',
#  'в санкт-петербурге было совершено покушение',
#  'в санкт-петербурге а вернее в петербургском отделении национального института прессы',
#  'в санкт-петербурге а вернее в петербургском отделении яблока считают поджог',
#  'в санкт-петербурге на подготовку и переподготовку кадров для новых предприятий электронной промышленности зеленограда',
#  'в санкт-петербурге избит кандидат в президенты россии',
#  'в санкт-петербурге на подготовку и переподготовку кадров для новых солдат сценарий учения будет основываться на подлинных документах',
#  'в санкт-петербурге на подготовку и переподготовку кадров для новых солдат сценарий учения будет основываться на американской бирже nasdaq',
#  'в санкт-петербурге на подготовку и переподготовку кадров для новых предприятий электронной промышленности',
#  'в санкт-петербурге на подготовку и переподготовку кадров для новых солдат сценарий учения будет основываться на американской бирже']

# %% [markdown]
# Пример из первого задания:
#
# ```управделами президента павлом бородиным именно он может произойти землетрясение силой почти 8 баллов принес обширные наводнения и оползни ```

# %%
generate_with_beam_search(
    matrix_news, id2word_news,
    bigram2id_news, max_beams=10, n=2,
    prompt="управделами президента"
)
# Out:
# ['управделами президента в кодорском ущелье абхазии',
#  'управделами президента в кодорском ущелье ивери челидзе',
#  'управделами президента уверен что размеры аттракциона поразят зрителей',
#  'управделами президента в кодорском ущелье',
#  'управделами президента уверен что размеры финансовой преступности и коррупции наше право евгения третьякова',
#  'управделами президента уверен что размеры финансовой преступности и беззакония',
#  'управделами президента уверен что размеры финансовой преступности и беззакония жителя казани дмитрия бердникова',
#  'управделами президента уверен что размеры финансовой преступности и беззакония жителя казани дмитрия бердникова председателя всероссийского движения против преступности и беззакония',
#  'управделами президента уверен что размеры финансовой преступности и беззакония жителя казани дмитрия бердникова председателя всероссийского движения против преступности и беззакония жителя казани дмитрия бердникова',
#  'управделами президента уверен что размеры финансовой преступности и беззакония жителя казани дмитрия бердникова председателя всероссийского движения против преступности и беззакония жителя казани дмитрия бердникова председателя всероссийского общественного движения спас']

# %% [markdown]
# Пример из первого задания:
#
# ```канцелярия премьер-министра заявила о необходимости пресекать факты когда арендные ставки на распространение программы в рамках окончательного урегулирования ближневосточного конфликта```

# %%
generate_with_beam_search(
    matrix_news, id2word_news,
    bigram2id_news, max_beams=10, n=2,
    prompt="канцелярия премьер-министра"
)
# Out:
# ['канцелярия премьер-министра заявила о завершении поиска станции',
#  'канцелярия премьер-министра заявила о выдвижении кандидата получить его с победой',
#  'канцелярия премьер-министра заявила о выдвижении своей кандидатуры на руководящие посты',
#  'канцелярия премьер-министра заявила о своей готовности к наступлению 2000 года',
#  'канцелярия премьер-министра заявила о выдвижении своей кандидатуры на руководящие посты госдумы вице-спикером от правых станет борис немцов и виктор похмелкин эдуард воробьев и юрий паршаков',
#  'канцелярия премьер-министра заявила о выдвижении кандидата получить его с января 2000 года',
#  'канцелярия премьер-министра заявила о выдвижении своей кандидатуры на руководящие посты госдумы вице-спикером от правых станет борис немцов и виктор геращенко',
#  'канцелярия премьер-министра заявила о выдвижении своей кандидатуры на руководящие посты госдумы вице-спикером от группы поддержки анатолия быкова',
#  'канцелярия премьер-министра заявила о выдвижении своей кандидатуры на руководящие посты госдумы вице-спикером от правых станет борис немцов и виктор похмелкин от спс единства лдпр и движения',
#  'канцелярия премьер-министра заявила о выдвижении своей кандидатуры на руководящие посты госдумы вице-спикером от правых станет борис немцов и виктор похмелкин от спс единства лдпр и движения отечество вся россия']

# %% [markdown]
# Пример из первого задания:
#
# ```любой желающий может отправиться к примеру в великобритании лейбористской партии на всеобщих выборах робертсон стал министром обороны чечни магомедом ямбиевым```

# %%
generate_with_beam_search(
    matrix_news, id2word_news,
    bigram2id_news, max_beams=10, n=2,
    prompt="любой желающий"
)
# Out:
# ['любой желающий может отправиться к местам своего проживания',
#  'любой желающий может отправиться к местам раскопок под уэлен',
#  'любой желающий может отправиться к местам захоронения жертв сталинских репрессий в куропатах',
#  'любой желающий может отправиться к местам службы из-за конфликта между израилем и палестинской автономией',
#  'любой желающий может отправиться к местам службы из-за конфликта между волошиным и шабдурасуловым автономное поведение первого зама',
#  'любой желающий может отправиться к местам прежнего проживания стали возвращаться люди ранее выехавшие в центральные районы токио',
#  'любой желающий может отправиться к местам прежнего проживания стали возвращаться люди ранее выехавшие в центральные районы столицы бразилии',
#  'любой желающий может отправиться к местам прежнего проживания стали возвращаться люди ранее выехавшие в центральные регионы россии союз независимых депутатов',
#  'любой желающий может отправиться к местам прежнего проживания стали возвращаться люди ранее выехавшие в центральные военные округа более 100 тысяч человек',
#  'любой желающий может отправиться к местам прежнего проживания стали возвращаться люди ранее выехавшие в центральные регионы россии союз независимых депутатов будет утвержден сенатом то компании имеющие более 20 тысяч человек']

# %% [markdown]
# По сравнению с первым заданием наиболее вероятные генерации beam search
# - более короткие (токен eos имеет высокую вероятность)
# - более "предсказуемые" (по определению, потому что в первом задании мы семплировали по всему словарю)
